# %%
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

# %%
# Randomly generated data with two classes and plot it together.

X, y = make_classification(n_features=2, n_redundant=0, n_informative=2, random_state=1, n_clusters_per_class=1)

plt.figure(figsize=(12,8))
plt.scatter(X[:,0],X[:,1], c=y)
plt.show()

# %%
# Create a the sigmoid function
'''The range of inputs is the set of all Real Numbers and the range of outputs is between 0 and 1.
    z should increase positive infinity when the output get closer to 1'''

# Sigmoid formula --> 1/(1 + e−t)

def sigmoid(z):
    sig_func = 1/(1 + np.exp(-z))
    return sig_func


# test the function
sigmoid(2)
# Out:
# 0.8807970779778823

# %%
'''legend:
- y = true/target value --> (can be 0 or 1 only)
- y_hat = the hypotesis (the output values is between 0 and 1) --> Thread on towarddatascience.com
'''

# %%
# Cost function
